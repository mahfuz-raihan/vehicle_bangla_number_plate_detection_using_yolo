# %%
! nvidia-smi
# Out:
# Tue Jan  7 18:11:41 2025
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.104.05             Driver Version: 535.104.05   CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  Tesla T4                       Off | 00000000:00:04.0 Off |                    0 |
# | N/A   50C    P8               9W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                                         |                      |                  N/A |
# ...

# %%
! git clone https://github.com/THU-MIG/yolov10.git
# Out:
# Cloning into 'yolov10'...
# remote: Enumerating objects: 20332, done.
# remote: Total 20332 (delta 0), reused 0 (delta 0), pack-reused 20332 (from 1)
# Receiving objects: 100% (20332/20332), 11.09 MiB | 7.11 MiB/s, done.
# Resolving deltas: 100% (14352/14352), done.

# %%
# %cd /content/yolov10
# Out:
# /content/yolov10

# %%
ls
# Out:
# app.py           docs/      flops.py  mkdocs.yml      requirements.txt
# CONTRIBUTING.md  examples/  LICENSE   pyproject.toml  tests/
# docker/          figures/   logs/     README.md       ultralytics/

# %%
! cp -R /content/drive/MyDrive/license_detection/yolov10/custom_dataset /content/yolov10

# %% [markdown]
# ### Unzip the dataset
# ```Note```: make a ```.yaml``` file for dataset training

# %%
! pwd
# Out:
# /content/yolov10

# %%
#! unzip /content/drive/MyDrive/license_detection/custom_dataset.zip
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: content/drive/MyDrive/license_detection/yolov10/custom_dataset/license_plate_localization/train/labels/car-3110_jpg.rf.25722a176bd3108e673fa301d4a982ef.txt
#   inflating: content/drive/MyDrive/license_detection/yolov10/custom_dataset/license_plate_localization/train/labels/IMG_20190413_123918_jpg.rf.74a4035e18954b93c2f67466c8b36b43.txt
#   inflating: content/drive/MyDrive/license_detection/yolov10/custom_dataset/license_plate_localization/train/labels/IMG_20190413_121936_jpg.rf.cb8aed22139465634e1ba1789c3721a5.txt
#  extracting: content/drive/MyDrive/license_detection/yolov10/custom_dataset/license_plate_localization/train/labels/151265826_2324490967688099_7720382211564214138_n_jpg.rf.2d2cbff068eb44166049443432077bb5.txt
#   inflating: content/drive/MyDrive/license_detection/yolov10/custom_dataset/license_plate_localization/train/labels/car-3028_jpg.rf.0c2ff96abd632e005d997864cfdf16b3.txt
# ...

# %%
! pip install .
# Out:
# Processing /content/drive/MyDrive/license_detection/yolov10
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#   Created wheel for ultralytics: filename=ultralytics-8.1.34-py3-none-any.whl size=731420 sha256=61c392f7abb9da2ac83344705c7a5eff12efdd5cc7d7b910be72172758a48675
#   Stored in directory: /tmp/pip-ephem-wheel-cache-ygbsczdx/wheels/9d/4a/b4/3dd575b3550d363bac1eab4618511f3e65f167bf0bb59c2305
# Successfully built ultralytics
# ...

# %%
! pwd
# Out:
# /content/yolov10

# %%
# Let's download the model from the model zoo

import os
import urllib.request

# create a directroy for the weights in the current working directory
weights_dir = os.path.join(os.getcwd(), "weights")
os.makedirs(weights_dir, exist_ok=True)

# URL of the weight file
urls = [
    'https://github.com/ultralytics/assets/releases/download/v8.2.0/yolov10n.pt',
    'https://github.com/ultralytics/assets/releases/download/v8.2.0/yolov10s.pt',
    'https://github.com/ultralytics/assets/releases/download/v8.2.0/yolov10m.pt',
    'https://github.com/ultralytics/assets/releases/download/v8.2.0/yolov10b.pt',
    'https://github.com/ultralytics/assets/releases/download/v8.2.0/yolov10l.pt',
    'https://github.com/ultralytics/assets/releases/download/v8.2.0/yolov10x.pt'
]

# Download each file
for url in urls:
    file_name = os.path.join(weights_dir, os.path.basename(url))
    urllib.request.urlretrieve(url, file_name)
    print(f"Downloaded {file_name}")
# Out:
# Downloaded /content/yolov10/weights/yolov10n.pt
# Downloaded /content/yolov10/weights/yolov10s.pt
# Downloaded /content/yolov10/weights/yolov10m.pt
# Downloaded /content/yolov10/weights/yolov10b.pt
# Downloaded /content/yolov10/weights/yolov10l.pt
# Downloaded /content/yolov10/weights/yolov10x.pt

# %%
! git config credential.helper "netrc -d -v"

# %%
# now run the command below in the terminal
! yolo task=detect mode=train epochs=75 batch=16 patience=10 plots=True model=weights/yolov10n.pt data=data.yaml
# Out:
# /usr/local/lib/python3.10/dist-packages/ultralytics/nn/tasks.py:733: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   ckpt = torch.load(file, map_location="cpu")
# ...

# %%
! cp -R /content/yolov10/runs /content/drive/MyDrive/license_detection

# %%
! yolo task=detect mode=predict model=/content/yolov10/runs/detect/train2/weights/best.pt conf=0.25 source=/content/yolov10/car-2039_jpg.rf.7106d025ed7e34a237dd633758960dbd.jpg save=True
# Out:
# /usr/local/lib/python3.10/dist-packages/ultralytics/nn/tasks.py:733: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   ckpt = torch.load(file, map_location="cpu")
# ...

# %%
! cp -R /content/yolov10/runs/detect/predict/car-2039_jpg.rf.7106d025ed7e34a237dd633758960dbd.jpg /content/drive/MyDrive/license_detection

# %%
# %cd /content/drive/MyDrive/license_detection/yolov10
# Out:
# /content/drive/MyDrive/license_detection/yolov10

# %%
! yolo task=detect mode=predict model=/content/drive/MyDrive/license_detection/yolov10/runs/detect/train2/weights/best.pt conf=0.25 source=/content/drive/MyDrive/license_detection/yolov10/test_files/Screenshot_2.png save=True
# Out:
# /usr/local/lib/python3.10/dist-packages/ultralytics/nn/tasks.py:733: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   ckpt = torch.load(file, map_location="cpu")
# ...

# %%
! pwd
# Out:
# /content/drive/MyDrive/license_detection/yolov10
