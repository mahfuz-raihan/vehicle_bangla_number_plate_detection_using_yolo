# %%
! nvidia-smi
# Out:
# Thu Jan 16 03:02:50 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 560.35.05              Driver Version: 560.35.05      CUDA Version: 12.6     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA GeForce RTX 3060 Ti     Off |   00000000:01:00.0  On |                  N/A |
# |  0%   46C    P8             18W /  200W |     709MiB /   8192MiB |     16%      Default |
# |                                         |                        |                  N/A |
# ...

# %% [markdown]
# ## Some instruction for installation
# > Go ```yolov10``` directory install all necessary packages.

# %%
# Let's download the model from the model zoo

import os
import urllib.request

# create a directroy for the weights in the current working directory

weights_dir = os.path.join(os.getcwd(), "weights")
os.makedirs(weights_dir, exist_ok=True)

# URL of the weight file
urls = [
    'https://github.com/ultralytics/assets/releases/download/v8.2.0/yolov10n.pt',
    'https://github.com/ultralytics/assets/releases/download/v8.2.0/yolov10s.pt',
    'https://github.com/ultralytics/assets/releases/download/v8.2.0/yolov10m.pt',
    'https://github.com/ultralytics/assets/releases/download/v8.2.0/yolov10b.pt',
    'https://github.com/ultralytics/assets/releases/download/v8.2.0/yolov10l.pt',
    'https://github.com/ultralytics/assets/releases/download/v8.2.0/yolov10x.pt'
]

# Download each file
for url in urls:
    file_name = os.path.join(weights_dir, os.path.basename(url))
    urllib.request.urlretrieve(url, file_name)
    print(f"Downloaded {file_name}")
# Out:
# Downloaded /media/mahfuz/Media/work/number_plate_detection/New_work/weights/yolov10n.pt
# Downloaded /media/mahfuz/Media/work/number_plate_detection/New_work/weights/yolov10s.pt
# Downloaded /media/mahfuz/Media/work/number_plate_detection/New_work/weights/yolov10m.pt
# Downloaded /media/mahfuz/Media/work/number_plate_detection/New_work/weights/yolov10b.pt
# Downloaded /media/mahfuz/Media/work/number_plate_detection/New_work/weights/yolov10l.pt
# Downloaded /media/mahfuz/Media/work/number_plate_detection/New_work/weights/yolov10x.pt

# %%
# now run the command below in the terminal
! yolo task=detect mode=train epochs=50 batch=16 imgsz= 640 patience=10 device=0 workers=8 plots=True model=yolov10/weights/yolov10n.pt data=yolov10/data.yaml
# Out:
# New https://pypi.org/project/ultralytics/8.3.56 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.1.34 🚀 Python-3.11.0 torch-2.2.2+cu121 CUDA:0 (NVIDIA GeForce RTX 3060 Ti, 7862MiB)
# ...
